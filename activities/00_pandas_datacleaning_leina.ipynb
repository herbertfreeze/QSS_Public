# %% [markdown]
# ## 0. Load imports

# %%
## imports
import pandas as pd
import numpy as np


# ## print multiple things from same cell
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 0. Load data

# %%
## load data on 2020 crimes in DC
df = dc_crim_2020 = pd.read_csv("https://opendata.arcgis.com/datasets/f516e0dd7b614b088ad781b0c4002331_2.csv")
dc_crim_2020.head()
dc_crim_2020.shape
dc_crim_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27933 entries, 0 to 27932
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   X                     27933 non-null  float64
#  1   Y                     27933 non-null  float64
#  2   CCN                   27933 non-null  int64
#  3   REPORT_DAT            27933 non-null  object
#  4   SHIFT                 27933 non-null  object
#  5   METHOD                27933 non-null  object
#  6   OFFENSE               27933 non-null  object
#  7   BLOCK                 27933 non-null  object
#  8   XBLOCK                27933 non-null  float64
#  9   YBLOCK                27933 non-null  float64
#  10  WARD                  27933 non-null  int64
#  11  ANC                   27933 non-null  object
#  12  DISTRICT              27904 non-null  float64
#  13  PSA                   27898 non-null  float64
#  14  NEIGHBORHOOD_CLUSTER  27933 non-null  object
#  15  BLOCK_GROUP           27932 non-null  object
#  16  CENSUS_TRACT          27932 non-null  float64
#  17  VOTING_PRECINCT       27933 non-null  object
#  18  LATITUDE              27933 non-null  float64
#  19  LONGITUDE             27933 non-null  float64
#  20  BID                   4657 non-null   object
#  21  START_DATE            27932 non-null  object
#  22  END_DATE              24851 non-null  object
#  23  OBJECTID              27933 non-null  int64
#  24  OCTO_RECORD_ID        0 non-null      float64
# dtypes: float64(10), int64(3), object(12)
# memory usage: 5.3+ MB

# %%
df.columns
# Out:
# Index(['X', 'Y', 'CCN', 'REPORT_DAT', 'SHIFT', 'METHOD', 'OFFENSE', 'BLOCK',
#        'XBLOCK', 'YBLOCK', 'WARD', 'ANC', 'DISTRICT', 'PSA',
#        'NEIGHBORHOOD_CLUSTER', 'BLOCK_GROUP', 'CENSUS_TRACT',
#        'VOTING_PRECINCT', 'LATITUDE', 'LONGITUDE', 'BID', 'START_DATE',
#        'END_DATE', 'OBJECTID', 'OCTO_RECORD_ID'],
#       dtype='object')

# %%
df.OFFENSE
df.OFFENSE.value_counts()
# Out:
# OFFENSE
# THEFT/OTHER                   10927
# THEFT F/AUTO                   8283
# MOTOR VEHICLE THEFT            3260
# ROBBERY                        1998
# ASSAULT W/DANGEROUS WEAPON     1632
# BURGLARY                       1444
# HOMICIDE                        198
# SEX ABUSE                       178
# ARSON                            13
# Name: count, dtype: int64

# %%
plus_1 = lambda x: x + 1

# %%
df.X.apply(plus_1)
# Out:
# 0       -75.993094
# 1       -76.027049
# 2       -75.947655
# 3       -76.032861
# 4       -75.979766
#            ...
# 27928   -76.040861
# 27929   -76.020915
# 27930   -75.965994
# 27931   -76.024174
# 27932   -76.029716
# Name: X, Length: 27933, dtype: float64

# %% [markdown]
# #### Warm-up: Ways to add one to column X
# And how to time your code

# %% [markdown]
# ## 1. Aggregation

# %%
df[["WARD", "OFFENSE", "SHIFT"]]
# Out:
#        WARD                     OFFENSE    SHIFT
# 0         5                THEFT F/AUTO  EVENING
# 1         2                 THEFT/OTHER  EVENING
# 2         7                 THEFT/OTHER  EVENING
# 3         4                THEFT F/AUTO      DAY
# 4         5         MOTOR VEHICLE THEFT      DAY
# ...     ...                         ...      ...
# 27928     2                    BURGLARY      DAY
# 27929     6                 THEFT/OTHER      DAY
# 27930     7                    BURGLARY      DAY
# 27931     1  ASSAULT W/DANGEROUS WEAPON      DAY
# 27932     4                 THEFT/OTHER  EVENING
#
# [27933 rows x 3 columns]

# %%
for i, ddf in df.groupby("WARD"):
    break
ddf[["WARD", "OFFENSE", "SHIFT"]]
# Out:
#        WARD                     OFFENSE     SHIFT
# 8         1                     ROBBERY  MIDNIGHT
# 24        1                 THEFT/OTHER       DAY
# 27        1                 THEFT/OTHER       DAY
# 32        1                 THEFT/OTHER       DAY
# 46        1                THEFT F/AUTO   EVENING
# ...     ...                         ...       ...
# 27909     1                THEFT F/AUTO       DAY
# 27913     1         MOTOR VEHICLE THEFT   EVENING
# 27921     1                THEFT F/AUTO   EVENING
# 27924     1                THEFT F/AUTO  MIDNIGHT
# 27931     1  ASSAULT W/DANGEROUS WEAPON       DAY
#
# [3542 rows x 3 columns]

# %% [markdown]
# ### Example of grouping by one variable and doing one aggregation
#
# **Task**: find and print the number of unique offense types (`OFFENSE`) by ward (`WARD`)

# %%
offense_by_ward = df.groupby("WARD").agg({"OFFENSE" : "nunique"}).reset_index()
offense_by_ward
# Out:
#    WARD  OFFENSE
# 0     1        9
# 1     2        9
# 2     3        8
# 3     4        8
# 4     5        9
# 5     6        9
# 6     7        9
# 7     8        9

# %%
def get_unique(X):
    Y = X.unique()
    return len(Y)

# %%
offense_by_ward = df.groupby("WARD").agg({"OFFENSE" : get_unique}).reset_index()
offense_by_ward
# Out:
#    WARD  OFFENSE
# 0     1        9
# 1     2        9
# 2     3        8
# 3     4        8
# 4     5        9
# 5     6        9
# 6     7        9
# 7     8        9

# %% [markdown]
# ### Example of grouping by one variable and providing two summaries of the same variable
#
# **Task**: previous showed number of offenses by ward but want to find out content of offenses in each ward; create an aggregation that summarizes both the number of unique offenses by ward and what those offenses are -- for instance, by pasting the unique offenses in that ward separated by the ";" (e.g., Theft; Burglary;...)
#
# *Hint*: you can use the join command to paste together a list separated by some delimiter.
#     - The syntax, if we are using the comma delimiter, is: ", ".join(nameoflist)

# %%
offense_by_ward2 = df.groupby("WARD").agg({"OFFENSE" : ["nunique", "unique"]}).reset_index()
offense_by_ward2
# Out:
#   WARD OFFENSE
#        nunique                                             unique
# 0    1       9  [ROBBERY, THEFT/OTHER, THEFT F/AUTO, MOTOR VEH...
# 1    2       9  [THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEF...
# 2    3       8  [ASSAULT W/DANGEROUS WEAPON, THEFT/OTHER, THEF...
# 3    4       8  [THEFT F/AUTO, THEFT/OTHER, ROBBERY, MOTOR VEH...
# 4    5       9  [THEFT F/AUTO, MOTOR VEHICLE THEFT, ROBBERY, T...
# 5    6       9  [THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, BURG...
# 6    7       9  [THEFT/OTHER, BURGLARY, MOTOR VEHICLE THEFT, T...
# 7    8       9  [THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, HOMI...

# %%
def get_separated_list(X):
    Y = X.unique()
    return "; ".join(Y)

# %%
offense_by_ward2 = df.groupby("WARD").agg({"OFFENSE" : get_separated_list}).reset_index()
offense_by_ward2
# Out:
#    WARD                                            OFFENSE
# 0     1  ROBBERY; THEFT/OTHER; THEFT F/AUTO; MOTOR VEHI...
# 1     2  THEFT/OTHER; THEFT F/AUTO; MOTOR VEHICLE THEFT...
# 2     3  ASSAULT W/DANGEROUS WEAPON; THEFT/OTHER; THEFT...
# 3     4  THEFT F/AUTO; THEFT/OTHER; ROBBERY; MOTOR VEHI...
# 4     5  THEFT F/AUTO; MOTOR VEHICLE THEFT; ROBBERY; TH...
# 5     6  THEFT/OTHER; ASSAULT W/DANGEROUS WEAPON; BURGL...
# 6     7  THEFT/OTHER; BURGLARY; MOTOR VEHICLE THEFT; TH...
# 7     8  THEFT/OTHER; ASSAULT W/DANGEROUS WEAPON; HOMIC...

# %%
OF = df.groupby(["WARD"])["OFFENSE"].unique().apply(lambda x: "; ".join(x)).reset_index()
OF
# Out:
#    WARD                                            OFFENSE
# 0     1  ROBBERY; THEFT/OTHER; THEFT F/AUTO; MOTOR VEHI...
# 1     2  THEFT/OTHER; THEFT F/AUTO; MOTOR VEHICLE THEFT...
# 2     3  ASSAULT W/DANGEROUS WEAPON; THEFT/OTHER; THEFT...
# 3     4  THEFT F/AUTO; THEFT/OTHER; ROBBERY; MOTOR VEHI...
# 4     5  THEFT F/AUTO; MOTOR VEHICLE THEFT; ROBBERY; TH...
# 5     6  THEFT/OTHER; ASSAULT W/DANGEROUS WEAPON; BURGL...
# 6     7  THEFT/OTHER; BURGLARY; MOTOR VEHICLE THEFT; TH...
# 7     8  THEFT/OTHER; ASSAULT W/DANGEROUS WEAPON; HOMIC...

# %% [markdown]
# ### Example of grouping by two variables
#
# **Task**: group by ward (`WARD`) and police shift (`SHIFT`) and find the offense that is most common in that ward and shift

# %%
def most_common(X):
    Y = X.value_counts()
    return Y.index[0]

# %%
ward_shift = df.groupby(["WARD", "SHIFT"]).agg({"OFFENSE" : most_common}).reset_index()
ward_shift
# Out:
#     WARD     SHIFT                     OFFENSE
# 0      1       DAY                 THEFT/OTHER
# 1      1   EVENING                 THEFT/OTHER
# 2      1  MIDNIGHT                 THEFT/OTHER
# 3      2       DAY                 THEFT/OTHER
# 4      2   EVENING                 THEFT/OTHER
# 5      2  MIDNIGHT                 THEFT/OTHER
# 6      3       DAY                 THEFT/OTHER
# 7      3   EVENING                 THEFT/OTHER
# 8      3  MIDNIGHT                 THEFT/OTHER
# 9      4       DAY                THEFT F/AUTO
# 10     4   EVENING                 THEFT/OTHER
# 11     4  MIDNIGHT                 THEFT/OTHER
# 12     5       DAY                THEFT F/AUTO
# 13     5   EVENING                 THEFT/OTHER
# 14     5  MIDNIGHT                 THEFT/OTHER
# 15     6       DAY                 THEFT/OTHER
# 16     6   EVENING                 THEFT/OTHER
# 17     6  MIDNIGHT                 THEFT/OTHER
# 18     7       DAY                THEFT F/AUTO
# 19     7   EVENING                 THEFT/OTHER
# 20     7  MIDNIGHT                 THEFT/OTHER
# 21     8       DAY                THEFT F/AUTO
# 22     8   EVENING                 THEFT/OTHER
# 23     8  MIDNIGHT  ASSAULT W/DANGEROUS WEAPON

# %% [markdown]
# ## Summarizing over all rows or all columns (without grouping)
#
# We can also use the `apply` function to summarize rows or columns efficiently

# %% [markdown]
# **Task**: find the mean lat and longitude in one line of code

# %%
lat_long = df[["LATITUDE", "LONGITUDE"]].apply(np.mean)
lat_long
# Out:
# LATITUDE     38.907613
# LONGITUDE   -77.007049
# dtype: float64

# %% [markdown]
# ## 2. Creating new columns/transforming their type

# %% [markdown]
# ### Simple filtering
#
# `np.where` is in the numpy package (aliased as `np`) and operates similar to `ifelse` in R
#
# But there is a built in pandas way to emulate this.
#
# **Task**: create an indicator `is_theft` for any offense that contains the word "THEFT"
#
# **Task**: create an indicator `is_theft_notmotor` for any offense that contains the word "THEFT" but does not contain the word "MOTOR"

# %%
df["is_theft"] = df.OFFENSE.str.contains("THEFT")
df["is_theft_notmotor"] = (df.OFFENSE.str.contains("THEFT") == True) & (df.OFFENSE.str.contains("MOTOR") == False)
df
# Out:
#                X          Y       CCN              REPORT_DAT    SHIFT  \
# 0     -76.993094  38.928471  20153901  2020/10/27 20:37:21+00  EVENING
# 1     -77.027049  38.904911  20095149  2020/06/30 20:46:51+00  EVENING
# 2     -76.947655  38.896660  20064305  2020/04/27 23:44:04+00  EVENING
# 3     -77.032861  38.956717  20100388  2020/07/12 18:37:14+00      DAY
# 4     -76.979766  38.915804  20128992  2020/09/09 18:00:44+00      DAY
# ...          ...        ...       ...                     ...      ...
# 27928 -77.040861  38.905205  20109618  2020/08/01 15:12:23+00      DAY
# 27929 -77.020915  38.902526  20152852  2020/10/25 18:25:58+00      DAY
# 27930 -76.965994  38.876867  20020481  2020/02/03 16:50:47+00      DAY
# 27931 -77.024174  38.925028  20075827  2020/05/22 18:42:22+00      DAY
# 27932 -77.029716  38.940278  20075557  2020/05/22 02:24:34+00  EVENING
#
#        METHOD                     OFFENSE  \
# 0      OTHERS                THEFT F/AUTO
# 1      OTHERS                 THEFT/OTHER
# 2      OTHERS                 THEFT/OTHER
# 3      OTHERS                THEFT F/AUTO
# 4      OTHERS         MOTOR VEHICLE THEFT
# ...       ...                         ...
# 27928  OTHERS                    BURGLARY
# 27929  OTHERS                 THEFT/OTHER
# 27930  OTHERS                    BURGLARY
# 27931     GUN  ASSAULT W/DANGEROUS WEAPON
# 27932  OTHERS                 THEFT/OTHER
#
#                                               BLOCK    XBLOCK    YBLOCK  ...  \
# 0               900 - 999 BLOCK OF IRVING STREET NE  400599.0  140065.0  ...
# 1               1101 - 1199 BLOCK OF 11TH STREET NW  397654.0  137450.0  ...
# 2          4000 - 4121 BLOCK OF MINNESOTA AVENUE NE  404541.0  136535.0  ...
# 3          5500  - 5599 BLOCK OF COLORADO AVENUE NW  397152.0  143201.0  ...
# 4      2100 - 2131 BLOCK OF WEST VIRGINIA AVENUE NE  401755.0  138659.0  ...
# ...                                             ...       ...       ...  ...
# 27928    1130 - 1199 BLOCK OF CONNECTICUT AVENUE NW  396456.0  137483.0  ...
# 27929                600 - 699 BLOCK OF K STREET NW  398186.0  137185.0  ...
# 27930              2900 - 2999 BLOCK OF M STREET SE  402951.0  134337.0  ...
# 27931         700 - 799 BLOCK OF FAIRMONT STREET NW  397904.0  139683.0  ...
# 27932          4000  - 4099 BLOCK OF 13TH STREET NW  397424.0  141376.0  ...
#
#        VOTING_PRECINCT   LATITUDE  LONGITUDE                        BID  \
# 0          Precinct 73  38.928463 -76.993092                        NaN
# 1         Precinct 129  38.904904 -77.027047                        NaN
# 2          Precinct 99  38.896652 -76.947653                        NaN
# 3          Precinct 53  38.956709 -77.032858                        NaN
# 4          Precinct 76  38.915796 -76.979764                        NaN
# ...                ...        ...        ...                        ...
# 27928      Precinct 17  38.905197 -77.040859            GOLDEN TRIANGLE
# 27929      Precinct 18  38.902518 -77.020913  MOUNT VERNON TRIANGLE CID
# 27930     Precinct 111  38.876859 -76.965991                        NaN
# 27931      Precinct 37  38.925020 -77.024172                        NaN
# 27932      Precinct 47  38.940270 -77.029713                        NaN
#
#                    START_DATE                END_DATE   OBJECTID  \
# 0      2020/10/27 20:26:31+00  2020/10/27 20:37:29+00  398217667
# 1      2020/06/29 23:30:04+00  2020/06/30 11:00:09+00  398217668
# 2      2020/04/27 22:49:30+00                     NaN  398217670
# 3      2020/07/12 17:36:13+00  2020/07/12 18:10:45+00  398217673
# 4      2020/09/09 01:30:07+00  2020/09/10 23:00:57+00  398217674
# ...                       ...                     ...        ...
# 27928  2020/07/31 19:00:19+00  2020/08/01 15:13:33+00  398740090
# 27929  2020/10/25 17:00:17+00  2020/10/25 17:10:27+00  398740091
# 27930  2020/02/03 16:10:39+00  2020/02/03 16:50:48+00  398740098
# 27931  2020/05/22 17:27:34+00  2020/05/22 18:42:31+00  398740104
# 27932  2020/05/17 16:00:51+00  2020/05/20 21:00:59+00  398740106
#
#       OCTO_RECORD_ID  is_theft  is_theft_notmotor
# 0                NaN      True               True
# 1                NaN      True               True
# 2                NaN      True               True
# 3                NaN      True               True
# 4                NaN      True              False
# ...              ...       ...                ...
# 27928            NaN     False              False
# 27929            NaN      True               True
# 27930            NaN     False              False
# 27931            NaN     False              False
# 27932            NaN      True               True
#
# [27933 rows x 27 columns]

# %% [markdown]
# ### np.select
#
# **Task**: create a new variable, `offense_summary`, where you:
#
# - Recode theft offenses that use a gun or knife as the method (`METHOD`) as: violent theft
# - Recode non-theft offenses that use a gun or knife as the method as: violent other
# - Recode all other as non-violent

# %%
methods = ["violent theft", "violent other"]

conditions = [
    df.is_theft & (df.METHOD.isin(["GUN", "KNIFE"])),
    ~df.is_theft & (df.METHOD.isin(["GUN", "KNIFE"]))
]

df["offense_summary"] = np.select(conditions, methods, default="non-violent")
df.offense_summary.value_counts()
# Out:
# offense_summary
# non-violent      25257
# violent other     2641
# violent theft       35
# Name: count, dtype: int64

# %% [markdown]
# ### map.recode
#
# **Task**: recode shifts that are MIDNIGHT or EVENING as "nighttime"; code other shift to daytime

# %%
shifts_original = ["MIDNIGHT", "EVENING"]
shifts_new = ["nighttime", "nighttime"]

conversion_dict = dict(zip(shifts_original, shifts_new))

df["recoded_shift"] = df.SHIFT.map(conversion_dict).fillna("daytime")

# %%
df
# Out:
#                X          Y       CCN              REPORT_DAT    SHIFT  \
# 0     -76.993094  38.928471  20153901  2020/10/27 20:37:21+00  EVENING
# 1     -77.027049  38.904911  20095149  2020/06/30 20:46:51+00  EVENING
# 2     -76.947655  38.896660  20064305  2020/04/27 23:44:04+00  EVENING
# 3     -77.032861  38.956717  20100388  2020/07/12 18:37:14+00      DAY
# 4     -76.979766  38.915804  20128992  2020/09/09 18:00:44+00      DAY
# ...          ...        ...       ...                     ...      ...
# 27928 -77.040861  38.905205  20109618  2020/08/01 15:12:23+00      DAY
# 27929 -77.020915  38.902526  20152852  2020/10/25 18:25:58+00      DAY
# 27930 -76.965994  38.876867  20020481  2020/02/03 16:50:47+00      DAY
# 27931 -77.024174  38.925028  20075827  2020/05/22 18:42:22+00      DAY
# 27932 -77.029716  38.940278  20075557  2020/05/22 02:24:34+00  EVENING
#
#        METHOD                     OFFENSE  \
# 0      OTHERS                THEFT F/AUTO
# 1      OTHERS                 THEFT/OTHER
# 2      OTHERS                 THEFT/OTHER
# 3      OTHERS                THEFT F/AUTO
# 4      OTHERS         MOTOR VEHICLE THEFT
# ...       ...                         ...
# 27928  OTHERS                    BURGLARY
# 27929  OTHERS                 THEFT/OTHER
# 27930  OTHERS                    BURGLARY
# 27931     GUN  ASSAULT W/DANGEROUS WEAPON
# 27932  OTHERS                 THEFT/OTHER
#
#                                               BLOCK    XBLOCK    YBLOCK  ...  \
# 0               900 - 999 BLOCK OF IRVING STREET NE  400599.0  140065.0  ...
# 1               1101 - 1199 BLOCK OF 11TH STREET NW  397654.0  137450.0  ...
# 2          4000 - 4121 BLOCK OF MINNESOTA AVENUE NE  404541.0  136535.0  ...
# 3          5500  - 5599 BLOCK OF COLORADO AVENUE NW  397152.0  143201.0  ...
# 4      2100 - 2131 BLOCK OF WEST VIRGINIA AVENUE NE  401755.0  138659.0  ...
# ...                                             ...       ...       ...  ...
# 27928    1130 - 1199 BLOCK OF CONNECTICUT AVENUE NW  396456.0  137483.0  ...
# 27929                600 - 699 BLOCK OF K STREET NW  398186.0  137185.0  ...
# 27930              2900 - 2999 BLOCK OF M STREET SE  402951.0  134337.0  ...
# 27931         700 - 799 BLOCK OF FAIRMONT STREET NW  397904.0  139683.0  ...
# 27932          4000  - 4099 BLOCK OF 13TH STREET NW  397424.0  141376.0  ...
#
#        LONGITUDE                        BID              START_DATE  \
# 0     -76.993092                        NaN  2020/10/27 20:26:31+00
# 1     -77.027047                        NaN  2020/06/29 23:30:04+00
# 2     -76.947653                        NaN  2020/04/27 22:49:30+00
# 3     -77.032858                        NaN  2020/07/12 17:36:13+00
# 4     -76.979764                        NaN  2020/09/09 01:30:07+00
# ...          ...                        ...                     ...
# 27928 -77.040859            GOLDEN TRIANGLE  2020/07/31 19:00:19+00
# 27929 -77.020913  MOUNT VERNON TRIANGLE CID  2020/10/25 17:00:17+00
# 27930 -76.965991                        NaN  2020/02/03 16:10:39+00
# 27931 -77.024172                        NaN  2020/05/22 17:27:34+00
# 27932 -77.029713                        NaN  2020/05/17 16:00:51+00
#
#                      END_DATE   OBJECTID OCTO_RECORD_ID  is_theft  \
# 0      2020/10/27 20:37:29+00  398217667            NaN      True
# 1      2020/06/30 11:00:09+00  398217668            NaN      True
# 2                         NaN  398217670            NaN      True
# 3      2020/07/12 18:10:45+00  398217673            NaN      True
# 4      2020/09/10 23:00:57+00  398217674            NaN      True
# ...                       ...        ...            ...       ...
# 27928  2020/08/01 15:13:33+00  398740090            NaN     False
# 27929  2020/10/25 17:10:27+00  398740091            NaN      True
# 27930  2020/02/03 16:50:48+00  398740098            NaN     False
# 27931  2020/05/22 18:42:31+00  398740104            NaN     False
# 27932  2020/05/20 21:00:59+00  398740106            NaN      True
#
#       is_theft_notmotor  offense_summary  recoded_shift
# 0                  True      non-violent      nighttime
# 1                  True      non-violent      nighttime
# 2                  True      non-violent      nighttime
# 3                  True      non-violent        daytime
# 4                 False      non-violent        daytime
# ...                 ...              ...            ...
# 27928             False      non-violent        daytime
# 27929              True      non-violent        daytime
# 27930             False      non-violent        daytime
# 27931             False    violent other        daytime
# 27932              True      non-violent      nighttime
#
# [27933 rows x 29 columns]

# %% [markdown]
# ### Using built-in pandas methods
#
# Another way of creating variables, used either alone or in combination with np.where and np.select is to use pandas built in `str` methods
#
# Basic structure is: `df['namestringcol'].str.someoperation`

# %% [markdown]
# **Task**: using a `str` method, create a new variable--`OFFENSE_NOSP`--that replaces spaces in the `OFFENSE` column with underscores

# %%
df["OFFENSE_NOSP"] = df["OFFENSE"].str.replace(" ", "_")
df
# Out:
#                X          Y       CCN              REPORT_DAT    SHIFT  \
# 0     -76.993094  38.928471  20153901  2020/10/27 20:37:21+00  EVENING
# 1     -77.027049  38.904911  20095149  2020/06/30 20:46:51+00  EVENING
# 2     -76.947655  38.896660  20064305  2020/04/27 23:44:04+00  EVENING
# 3     -77.032861  38.956717  20100388  2020/07/12 18:37:14+00      DAY
# 4     -76.979766  38.915804  20128992  2020/09/09 18:00:44+00      DAY
# ...          ...        ...       ...                     ...      ...
# 27928 -77.040861  38.905205  20109618  2020/08/01 15:12:23+00      DAY
# 27929 -77.020915  38.902526  20152852  2020/10/25 18:25:58+00      DAY
# 27930 -76.965994  38.876867  20020481  2020/02/03 16:50:47+00      DAY
# 27931 -77.024174  38.925028  20075827  2020/05/22 18:42:22+00      DAY
# 27932 -77.029716  38.940278  20075557  2020/05/22 02:24:34+00  EVENING
#
#        METHOD                     OFFENSE  \
# 0      OTHERS                THEFT F/AUTO
# 1      OTHERS                 THEFT/OTHER
# 2      OTHERS                 THEFT/OTHER
# 3      OTHERS                THEFT F/AUTO
# 4      OTHERS         MOTOR VEHICLE THEFT
# ...       ...                         ...
# 27928  OTHERS                    BURGLARY
# 27929  OTHERS                 THEFT/OTHER
# 27930  OTHERS                    BURGLARY
# 27931     GUN  ASSAULT W/DANGEROUS WEAPON
# 27932  OTHERS                 THEFT/OTHER
#
#                                               BLOCK    XBLOCK    YBLOCK  ...  \
# 0               900 - 999 BLOCK OF IRVING STREET NE  400599.0  140065.0  ...
# 1               1101 - 1199 BLOCK OF 11TH STREET NW  397654.0  137450.0  ...
# 2          4000 - 4121 BLOCK OF MINNESOTA AVENUE NE  404541.0  136535.0  ...
# 3          5500  - 5599 BLOCK OF COLORADO AVENUE NW  397152.0  143201.0  ...
# 4      2100 - 2131 BLOCK OF WEST VIRGINIA AVENUE NE  401755.0  138659.0  ...
# ...                                             ...       ...       ...  ...
# 27928    1130 - 1199 BLOCK OF CONNECTICUT AVENUE NW  396456.0  137483.0  ...
# 27929                600 - 699 BLOCK OF K STREET NW  398186.0  137185.0  ...
# 27930              2900 - 2999 BLOCK OF M STREET SE  402951.0  134337.0  ...
# 27931         700 - 799 BLOCK OF FAIRMONT STREET NW  397904.0  139683.0  ...
# 27932          4000  - 4099 BLOCK OF 13TH STREET NW  397424.0  141376.0  ...
#
#                              BID              START_DATE  \
# 0                            NaN  2020/10/27 20:26:31+00
# 1                            NaN  2020/06/29 23:30:04+00
# 2                            NaN  2020/04/27 22:49:30+00
# 3                            NaN  2020/07/12 17:36:13+00
# 4                            NaN  2020/09/09 01:30:07+00
# ...                          ...                     ...
# 27928            GOLDEN TRIANGLE  2020/07/31 19:00:19+00
# 27929  MOUNT VERNON TRIANGLE CID  2020/10/25 17:00:17+00
# 27930                        NaN  2020/02/03 16:10:39+00
# 27931                        NaN  2020/05/22 17:27:34+00
# 27932                        NaN  2020/05/17 16:00:51+00
#
#                      END_DATE   OBJECTID OCTO_RECORD_ID is_theft  \
# 0      2020/10/27 20:37:29+00  398217667            NaN     True
# 1      2020/06/30 11:00:09+00  398217668            NaN     True
# 2                         NaN  398217670            NaN     True
# 3      2020/07/12 18:10:45+00  398217673            NaN     True
# 4      2020/09/10 23:00:57+00  398217674            NaN     True
# ...                       ...        ...            ...      ...
# 27928  2020/08/01 15:13:33+00  398740090            NaN    False
# 27929  2020/10/25 17:10:27+00  398740091            NaN     True
# 27930  2020/02/03 16:50:48+00  398740098            NaN    False
# 27931  2020/05/22 18:42:31+00  398740104            NaN    False
# 27932  2020/05/20 21:00:59+00  398740106            NaN     True
#
#        is_theft_notmotor offense_summary  recoded_shift  \
# 0                   True     non-violent      nighttime
# 1                   True     non-violent      nighttime
# 2                   True     non-violent      nighttime
# 3                   True     non-violent        daytime
# 4                  False     non-violent        daytime
# ...                  ...             ...            ...
# 27928              False     non-violent        daytime
# 27929               True     non-violent        daytime
# 27930              False     non-violent        daytime
# 27931              False   violent other        daytime
# 27932               True     non-violent      nighttime
#
#                      OFFENSE_NOSP
# 0                    THEFT_F/AUTO
# 1                     THEFT/OTHER
# 2                     THEFT/OTHER
# 3                    THEFT_F/AUTO
# 4             MOTOR_VEHICLE_THEFT
# ...                           ...
# 27928                    BURGLARY
# 27929                 THEFT/OTHER
# 27930                    BURGLARY
# 27931  ASSAULT_W/DANGEROUS_WEAPON
# 27932                 THEFT/OTHER
#
# [27933 rows x 30 columns]

# %% [markdown]
# ### Transforming column types
#
# **Task**: check the type of the `START_DATE` column

# %%
df.START_DATE
# Out:
# 0        2020/10/27 20:26:31+00
# 1        2020/06/29 23:30:04+00
# 2        2020/04/27 22:49:30+00
# 3        2020/07/12 17:36:13+00
# 4        2020/09/09 01:30:07+00
#                   ...
# 27928    2020/07/31 19:00:19+00
# 27929    2020/10/25 17:00:17+00
# 27930    2020/02/03 16:10:39+00
# 27931    2020/05/22 17:27:34+00
# 27932    2020/05/17 16:00:51+00
# Name: START_DATE, Length: 27933, dtype: object

# %%
df["START_DATE"].dtypes
# Out:
# dtype('O')

# %%
type(df.START_DATE)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Task**: recast the `START_DATE` column to datetime, calling this `START_DATE_CLEAN`; coerce errors rather than cleaning the string; check the type of that new col

# %%
df["START_DATE_CLEAN"] = pd.to_datetime(df.START_DATE, errors="coerce")
df["START_DATE_CLEAN"].dtypes
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# **Task:** print the min and max of `START_DATE_CLEAN`. What happens if you try to do this with `START_DATE`?

# %%
print(df.START_DATE_CLEAN.min())
print(df.START_DATE_CLEAN.max())
# Out:
# 1940-02-17 00:00:16+00:00
# 2021-01-01 02:30:21+00:00

# %%
print(df.START_DATE.min())
print(df.START_DATE.max())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(df.START_DATE.min())
#       2 print(df.START_DATE.max())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6179, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6171 @doc(make_doc("min", ndim=1))
#    6172 def min(
#    6173     self,
#    (...)
#    6177     **kwargs,
#    6178 ):
# -> 6179     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11946, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11939 def min(
#   11940     self,
#   11941     axis: Axis | None = 0,
#    (...)
#   11944     **kwargs,
#   11945 ):
# > 11946     return self._stat_function(
#   11947         "min",
#   11948         nanops.nanmin,
#   11949         axis,
#   11950         skipna,
#   11951         numeric_only,
#   11952         **kwargs,
#   11953     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11931 nv.validate_func(name, (), kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6124     # GH#47500 - change to TypeError to match other methods
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1092, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1087     return _na_for_min_count(values, axis)
#    1089 values, mask = _get_values(
#    1090     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1091 )
# -> 1092 result = getattr(values, meth)(axis)
#    1093 result = _maybe_null_out(result, axis, mask, values.shape)
#    1094 return result
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %% [markdown]
# ## 3. Row and column filtering

# %% [markdown]
# ### Row subsetting
#
# **Task**: filter to crime reports about theft using the `is_theft` definition and that are in ward 3

# %%
filter1 = df[df["is_theft"] & (df.WARD == 3)]
filter1.head()
# Out:
#             X          Y       CCN              REPORT_DAT     SHIFT  METHOD  \
# 11 -77.051908  38.924199  20170566  2020/11/30 20:53:51+00   EVENING  OTHERS
# 18 -77.083768  38.960042  20121641  2020/08/26 03:29:34+00  MIDNIGHT  OTHERS
# 28 -77.060408  38.938806  20160695  2020/11/10 05:15:06+00  MIDNIGHT  OTHERS
# 59 -77.074228  38.962589  20035501  2020/02/27 22:44:09+00   EVENING  OTHERS
# 74 -77.056309  38.933503  20001654  2020/01/03 20:09:51+00   EVENING  OTHERS
#
#          OFFENSE                                       BLOCK    XBLOCK  \
# 11   THEFT/OTHER  2600 - 2649 BLOCK OF CONNECTICUT AVENUE NW  395499.0
# 18  THEFT F/AUTO         5300 - 5399 BLOCK OF 43RD STREET NW  392740.0
# 28   THEFT/OTHER  3700 - 3899 BLOCK OF CONNECTICUT AVENUE NW  394763.0
# 59   THEFT/OTHER  5420 - 5499 BLOCK OF CONNECTICUT AVENUE NW  393567.0
# 74  THEFT F/AUTO       2700 - 2899 BLOCK OF MACOMB STREET NW  395118.0
#
#       YBLOCK  ...              START_DATE                END_DATE   OBJECTID  \
# 11  139592.0  ...  2020/11/30 16:45:06+00  2020/11/30 17:30:13+00  398217704
# 18  143573.0  ...  2020/08/25 22:30:03+00  2020/08/26 01:00:04+00  398217732
# 28  141214.0  ...  2020/11/10 03:47:06+00  2020/11/10 05:15:44+00  398217791
# 59  143855.0  ...  2020/02/27 18:50:10+00  2020/02/27 22:00:06+00  398217992
# 74  140625.0  ...  2020/01/03 19:38:39+00  2020/01/03 20:10:05+00  398218125
#
#     OCTO_RECORD_ID is_theft is_theft_notmotor  offense_summary recoded_shift  \
# 11             NaN     True              True      non-violent     nighttime
# 18             NaN     True              True      non-violent     nighttime
# 28             NaN     True              True      non-violent     nighttime
# 59             NaN     True              True      non-violent     nighttime
# 74             NaN     True              True      non-violent     nighttime
#
#     OFFENSE_NOSP          START_DATE_CLEAN
# 11   THEFT/OTHER 2020-11-30 16:45:06+00:00
# 18  THEFT_F/AUTO 2020-08-25 22:30:03+00:00
# 28   THEFT/OTHER 2020-11-10 03:47:06+00:00
# 59   THEFT/OTHER 2020-02-27 18:50:10+00:00
# 74  THEFT_F/AUTO 2020-01-03 19:38:39+00:00
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Column subsetting

# %% [markdown]
# **Task**: select two columns--`START_DATE` and `END_DATE`--and print the head of the dataframe

# %%
cols = ["START_DATE", "END_DATE"]
filter2 = df[cols]
filter2.head()
# Out:
#                START_DATE                END_DATE
# 0  2020/10/27 20:26:31+00  2020/10/27 20:37:29+00
# 1  2020/06/29 23:30:04+00  2020/06/30 11:00:09+00
# 2  2020/04/27 22:49:30+00                     NaN
# 3  2020/07/12 17:36:13+00  2020/07/12 18:10:45+00
# 4  2020/09/09 01:30:07+00  2020/09/10 23:00:57+00

# %% [markdown]
# **Task**: use list comprehension to automate this a bit and select all columns with the word "DATE" in the name; print the head of the dataframe

# %%
cols2 = [col for col in df.columns if "DATE" in col]
filter3 = df[cols2]
filter3.head()
# Out:
#                START_DATE                END_DATE          START_DATE_CLEAN
# 0  2020/10/27 20:26:31+00  2020/10/27 20:37:29+00 2020-10-27 20:26:31+00:00
# 1  2020/06/29 23:30:04+00  2020/06/30 11:00:09+00 2020-06-29 23:30:04+00:00
# 2  2020/04/27 22:49:30+00                     NaN 2020-04-27 22:49:30+00:00
# 3  2020/07/12 17:36:13+00  2020/07/12 18:10:45+00 2020-07-12 17:36:13+00:00
# 4  2020/09/09 01:30:07+00  2020/09/10 23:00:57+00 2020-09-09 01:30:07+00:00

# %% [markdown]
# **Task**: filter reports of crime in `START_DATE_CLEAN` before May 2020 and that are located in ward 1; select the ward and `START_DATE` column and print a random sample of rows

# %%
cols3 = ["WARD", "START_DATE_CLEAN"]
filter4 = df[cols3]
filter4 = filter4[(filter4["START_DATE_CLEAN"] < "2020-05-01") & (filter4["WARD"] == 1)]
filter4.sample(10)
# Out:
#        WARD          START_DATE_CLEAN
# 10528     1 2020-01-18 16:11:40+00:00
# 6792      1 2020-01-25 04:00:02+00:00
# 12073     1 2020-01-29 19:00:45+00:00
# 14794     1 2020-02-02 23:45:29+00:00
# 11954     1 2020-01-12 06:00:51+00:00
# 21219     1 2020-01-19 01:00:20+00:00
# 27909     1 2020-01-23 02:00:17+00:00
# 27085     1 2020-04-24 20:15:15+00:00
# 27184     1 2020-03-16 23:00:28+00:00
# 6683      1 2020-04-05 23:00:33+00:00
